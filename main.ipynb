# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# load data into a pandas DataFrame
savant_df = pd.read_csv("savant_data.csv")
savant_df.head()

# select relevant columns for analysis
columns_of_interest = [
    "player_name",
    "player_id",
    "slg", # slugging percentage
    "hrs", # home runs
    "obp" # on-base percentage
]
savant_df = savant_df[columns_of_interest]
savant_df.head()
# Out:
#         player_name  player_id    slg  hrs    obp
# 0  Arozarena, Randy     668227  0.432   32  0.347
# 1      Raleigh, Cal     663728  0.531   67  0.335
# 2    Crawford, J.P.     641487  0.365   18  0.350
# 3  Rodríguez, Julio     677594  0.462   40  0.323
# 4    Polanco, Jorge     593871  0.495   26  0.326
